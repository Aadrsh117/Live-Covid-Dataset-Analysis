# %%
import pandas as pd
import numpy as np

# %%
covid=pd.read_csv('dataset/Latest Covid-19 India Status.csv')

# %% [markdown]
#  ## 1. Print First And Last 10 Values From The Dataframe?

# %%
covid.head(10)

# %%
covid.tail(10)

# %% [markdown]
# ## 2. How many Rows & Columns in Dataframe?

# %%
print('Number of Rows = ',covid.shape[0])
print('Number of columns = ',covid.shape[1])

# %% [markdown]
# ## 3. Display Data Types Of Each Column?

# %%
covid.dtypes

# %% [markdown]
# ## 4. Find Out The State Which Has Minimum Total Cases?

# %%
covid.loc[covid['Total Cases'].idxmin(), 'State/UTs']
# Out:
# 'Andaman and Nicobar'

# %%
covid.loc[covid['Total Cases'].idxmin()]
# Out:
# State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object

# %% [markdown]
# ## 5. Find Out The State Which Has Maximum Total Cases?

# %%
covid.loc[covid['Total Cases'].idxmax(), 'State/UTs']
# Out:
# 'Maharashtra'

# %% [markdown]
# ## 6. Display All States Of India From DataFrame?

# %%
covid["State/UTs"]
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %%
pd.DataFrame(covid["State/UTs"])

# %% [markdown]
# ## 7. Display All The Data Of States Having Deaths Greater Than 10000?

# %%
covid[(covid['Deaths']>10000)]
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1   Andhra Pradesh      2340676       0     2325943   14733          0.00
# 4            Bihar       855267       1      842952   12314          0.00
# 6     Chhattisgarh      1187695       0     1173505   14190          0.00
# 8            Delhi      2040910      14     2014230   26666          0.00
# 10         Gujarat      1291383       5     1280299   11079          0.00
# 11         Haryana      1078903      27     1068121   10755          0.00
# 15       Karnataka      4088769      12     4048399   40358          0.00
# 16          Kerala      6907241      18     6835181   72042          0.00
# 19  Madhya Pradesh      1056351       0     1045565   10786          0.00
# 20     Maharashtra      8171048     214     8022276  148558          0.00
# 27          Punjab       793644    1233      773073   19338          0.16
# 30      Tamil Nadu      3610655       5     3572569   38081          0.00
# ...

# %% [markdown]
# ## 8. Count The Total Cases Of India?

# %%
covid['Total Cases'].sum()
# Out:
# 44999085

# %% [markdown]
# ## 9. What is the Death Ratio Of Maharashtra?

# %%
covid['Death Ratio'][20]
# Out:
# 1.82

# %%
covid[covid['State/UTs']=='Maharashtra']['Death Ratio']
# Out:
# 20    1.82
# Name: Death Ratio, dtype: float64

# %% [markdown]
# ## 10. Which State Has Minimum Death Ratio?

# %%
covid.loc[covid['Death Ratio'].idxmin(), 'State/UTs']
# Out:
# 'Dadra and Nagar Haveli and Daman and Diu'

# %%
covid[covid['Death Ratio'] == covid['Death Ratio'].min()]['State/UTs'].values[0]
# Out:
# 'Dadra and Nagar Haveli and Daman and Diu'

# %% [markdown]
# ## 11. Find Out The Discharged Patients From The States Maharashtra,Karnataka,MP,Gujrat?

# %%
covid[covid['State/UTs'].isin(['Maharashtra', 'Karnataka', 'Madhya Pradesh', 'Gujarat'])]['Discharged']
# Out:
# 10    1280299
# 15    4048399
# 19    1045565
# 20    8022276
# Name: Discharged, dtype: int64

# %%
print('Discharged patient from Maharashtra=',covid['Discharged'][20])
print('Discharged patient from Karnataka=',covid['Discharged'][15])
print('Discharged patient from Madhya Pradesh=',covid['Discharged'][19])
print('Discharged patient from Gujarat=',covid['Discharged'][10])
# Out:
# Discharged patient from Maharashtra= 8022276
# Discharged patient from Karnataka= 4048399
# Discharged patient from Madhya Pradesh= 1045565
# Discharged patient from Gujarat= 1280299

# %% [markdown]
# ## 12. Find Out The States Having Total Cases between 1 lac to 5 lac?

# %%
covid[(covid['Total Cases']>100000) & (covid['Total Cases']<500000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 5          Chandigarh       100693       0       99508    1185           0.0
# 9                 Goa       263346       3      259329    4014           0.0
# 12   Himachal Pradesh       322905       4      318660    4241           0.0
# 13  Jammu and Kashmir       482023       0      477231    4792           0.0
# 14          Jharkhand       443826       1      438491    5334           0.0
# 21            Manipur       140034       0      137885    2149           0.0
# 23            Mizoram       239560       1      238825     734           0.0
# 26         Puducherry       177547       0      175566    1981           0.0
# 32            Tripura       108493       1      107550     942           0.0
# 34        Uttarakhand       452571       0      444803    7768           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 5             98.82         1.18    30501026
# ...

# %%
covid[(covid['Total Cases']>100000) & (covid['Total Cases']<500000)]['State/UTs']
# Out:
# 5            Chandigarh
# 9                   Goa
# 12     Himachal Pradesh
# 13    Jammu and Kashmir
# 14            Jharkhand
# 21              Manipur
# 23              Mizoram
# 26           Puducherry
# 32              Tripura
# 34          Uttarakhand
# Name: State/UTs, dtype: object

# %% [markdown]
# ## 13. Display All The Data Of The States Which Has Active Cases Less Than 1000?

# %%
m=covid[(covid['Active']<1000)]
m
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %% [markdown]
#  ## 14. Make A Separate CSV File Of Data Of The States Which Has Active Cases Less Than 1000?

# %%
m.to_csv('dataset/states.csv',index=False)

# %% [markdown]
# ## 15. Total Number Of Deaths In India?

# %%
covid['Deaths'].sum()
# Out:
# 532027

# %% [markdown]
# ## 16. Top 10 highest Population States in India?

# %%
covid.sort_values(by='Population',ascending=False).head(10)
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 1                             Andhra Pradesh      2340676       0     2325943
# 14                                 Jharkhand       443826       1      438491
# 0                        Andaman and Nicobar        10766       0       10637
# 16                                    Kerala      6907241      18     6835181
# 34                               Uttarakhand       452571       0      444803
# 29                                    Sikkim        44927       4       44422
# 22                                 Meghalaya        96983       3       95352
# 10                                   Gujarat      1291383       5     1280299
# 31                                 Telengana       844432       8      840313
#
#     Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# ...

# %%
covid.loc[covid.sort_values(by='Population',ascending=False).index.tolist(),['State/UTs','Population']].head(10)
# Out:
#                                    State/UTs  Population
# 7   Dadra and Nagar Haveli and Daman and Diu   231502578
# 1                             Andhra Pradesh   128500364
# 14                                 Jharkhand   124904071
# 0                        Andaman and Nicobar   100896618
# 16                                    Kerala    91702478
# 34                               Uttarakhand    85002417
# 29                                    Sikkim    83697770
# 22                                 Meghalaya    79502477
# 10                                   Gujarat    70400153
# 31                                 Telengana    69599762
